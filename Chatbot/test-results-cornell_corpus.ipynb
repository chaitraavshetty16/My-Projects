# %%
import tensorflow as tf
import tensorlayer as tl
import numpy as np
from tensorlayer.cost import cross_entropy_seq, cross_entropy_seq_with_mask
from tqdm import tqdm
from sklearn.utils import shuffle
from data.cornell_corpus import data
from tensorlayer.models.seq2seq import Seq2seq
from tensorlayer.models.seq2seq_with_attention import Seq2seqLuongAttention
import os

# %% [markdown]
# # Load saved model and required vectorizer for data preprocessing

# %%
def initial_setup(data_corpus):
    metadata, idx_q, idx_a = data.load_data(PATH='data/{}/'.format(data_corpus))
    (trainX, trainY), (testX, testY), (validX, validY) = data.split_dataset(idx_q, idx_a)
    trainX = tl.prepro.remove_pad_sequences(trainX.tolist())
    trainY = tl.prepro.remove_pad_sequences(trainY.tolist())
    testX = tl.prepro.remove_pad_sequences(testX.tolist())
    testY = tl.prepro.remove_pad_sequences(testY.tolist())
    validX = tl.prepro.remove_pad_sequences(validX.tolist())
    validY = tl.prepro.remove_pad_sequences(validY.tolist())
    return metadata, trainX, trainY, testX, testY, validX, validY


data_corpus = "cornell_corpus"
#data preprocessing
metadata, trainX, trainY, testX, testY, validX, validY = initial_setup(data_corpus)


batch_size = 32
src_vocab_size = len(metadata['idx2w']) # 8002 (0~8001)
emb_dim = 1024

word2idx = metadata['w2idx']   # dict  word 2 index
idx2word = metadata['idx2w']   # list index 2 word

unk_id = word2idx['unk']   # 1
pad_id = word2idx['_']     # 0

start_id = src_vocab_size  # 8002
end_id = src_vocab_size + 1  # 8003

word2idx.update({'start_id': start_id})
word2idx.update({'end_id': end_id})
idx2word = idx2word + ['start_id', 'end_id']

src_vocab_size = tgt_vocab_size = src_vocab_size + 2

num_epochs = 1
vocabulary_size = src_vocab_size
decoder_seq_length = 20


def inference(seed, top_n):
    model_.eval()
    seed_id = [word2idx.get(w, unk_id) for w in seed.split(" ")]
    sentence_id = model_(inputs=[[seed_id]], seq_length=20, start_token=start_id, top_n = top_n)
    sentence = []
    for w_id in sentence_id[0]:
        w = idx2word[w_id]
        if w == 'end_id':
            break
        sentence = sentence + [w]
    return sentence

# create model object
model_ = Seq2seq(
        decoder_seq_length = decoder_seq_length,
        cell_enc=tf.keras.layers.GRUCell,
        cell_dec=tf.keras.layers.GRUCell,
        n_layer=3,
        n_units=256,
        embedding_layer=tl.layers.Embedding(vocabulary_size=vocabulary_size, embedding_size=emb_dim),
        )
    
optimizer = tf.optimizers.Adam(learning_rate=0.001)

# Load the pretrained model
load_weights = tl.files.load_npz(name='model-cornell_corpus.npz')
tl.files.assign_weights(load_weights, model_)
# Out:
# [TL] Embedding embedding_1: (8004, 1024)
# [TL] RNN rnn_1: cell: GRUCell, n_units: 256
# [TL] RNN rnn_2: cell: GRUCell, n_units: 256
# [TL] RNN rnn_3: cell: GRUCell, n_units: 256
# [TL] RNN rnn_4: cell: GRUCell, n_units: 256
# [TL] RNN rnn_5: cell: GRUCell, n_units: 256
# [TL] RNN rnn_6: cell: GRUCell, n_units: 256
# [TL] Reshape reshape_1
# [TL] Dense  dense_1: 8004 No Activation
# [TL] Reshape reshape_2
# [TL] Reshape reshape_3
# [<tf.Variable 'UnreadVariable' shape=(1024, 768) dtype=float32, numpy=
#  array([[-0.03148898,  0.13925529, -0.29645008, ..., -0.11974213,
#           0.03786283, -0.1295784 ],
#         [ 0.17386591,  0.06829999, -0.0285179 , ..., -0.37609744,
#           0.04056163,  0.23004293],
#         [-0.02074117,  0.27572682,  0.32532418, ..., -0.09201859,
#          -0.14367212, -0.08592128],
#         ...,
#         [-0.5577352 ,  0.18776865,  0.17842697, ..., -0.06257067,
#           0.16745389,  0.07865053],
#         [-0.01389502, -0.16177991,  0.0844833 , ..., -0.01332104,
#          -0.11778299,  0.08262827],
#         [ 0.132198  ,  0.16552937, -0.2364373 , ...,  0.08745446,
#           0.1203819 , -0.06019237]], dtype=float32)>,
#  <tf.Variable 'UnreadVariable' shape=(256, 768) dtype=float32, numpy=
#  array([[ 0.2109836 ,  0.22751983, -0.20228454, ...,  0.06346867,
#          -0.22863933,  0.2537897 ],
#         [-0.07739688,  0.00729488,  0.17323415, ..., -0.07905708,
#           0.08564501,  0.11764973],
#         [-0.19853431, -0.10668137,  0.00946648, ...,  0.11015932,
#           0.14726806,  0.14749205],
#         ...,
#         [-0.29154775,  0.25981128,  0.15256278, ..., -0.01999347,
#          -0.04010249,  0.31960747],
#         [-0.06369549, -0.0705404 ,  0.15883301, ..., -0.3679466 ,
#          -0.3054141 ,  0.02302113],
#         [-0.37448892, -0.09728166, -0.36560848, ...,  0.22652166,
#          -0.47958857,  0.48023874]], dtype=float32)>,
#  <tf.Variable 'UnreadVariable' shape=(2, 768) dtype=float32, numpy=
#  array([[-0.23599443, -0.01943666, -0.14282775, ..., -0.25812823,
#           0.08854679, -0.30299497],
#         [-0.23599443, -0.01943666, -0.14282775, ..., -0.35875165,
#          -0.06345548, -0.20637563]], dtype=float32)>,
#  <tf.Variable 'UnreadVariable' shape=(256, 768) dtype=float32, numpy=
#  array([[-0.12703869,  0.418259  , -0.35852295, ...,  0.2492101 ,
#          -0.05723756,  0.04734849],
#         [ 0.40347075,  0.77294505,  0.0609226 , ...,  0.05219381,
#          -0.1086272 ,  0.35078746],
#         [-0.54491687, -0.51432073, -0.17651923, ...,  0.6506927 ,
#          -0.15090957, -0.19455187],
#         ...,
#         [ 0.05313989, -0.02848412,  0.03246913, ..., -0.20590699,
#          -0.04909765, -0.17913592],
#         [-0.40437865, -0.18722178,  0.31011757, ...,  0.40515566,
#          -0.41375494,  0.18507367],
#         [-0.07170328,  0.42412356, -0.22427218, ..., -0.1729543 ,
#           0.16887565, -0.29743066]], dtype=float32)>,
#  <tf.Variable 'UnreadVariable' shape=(256, 768) dtype=float32, numpy=
#  array([[-0.3791474 , -0.17910226, -0.12546626, ...,  0.25816947,
#          -0.1960192 , -0.09520746],
#         [ 0.14028327,  0.49807635, -0.40951976, ...,  0.20808771,
#           0.25726736, -0.00713562],
#         [ 0.08241523, -0.1241337 ,  0.46319443, ..., -0.23032214,
#          -0.1733326 , -0.04385359],
#         ...,
#         [ 0.23061833,  0.33440605,  0.00381077, ..., -0.1550038 ,
#          -0.22751126,  0.25133163],
#         [-0.18677066, -0.28829655, -0.03352557, ..., -0.24442665,
#           0.16602756,  0.06791728],
#         [ 0.21281178,  0.27304447,  0.15761928, ...,  0.10821369,
#          -0.0248676 , -0.4281203 ]], dtype=float32)>,
#  <tf.Variable 'UnreadVariable' shape=(2, 768) dtype=float32, numpy=
#  array([[-0.04252187, -0.2183565 ,  0.2670581 , ...,  0.05136522,
#           0.04893164, -0.20601457],
#         [-0.04252187, -0.2183565 ,  0.2670581 , ...,  0.00305214,
#           0.04962178, -0.22299242]], dtype=float32)>,
#  <tf.Variable 'UnreadVariable' shape=(256, 768) dtype=float32, numpy=
#  array([[-0.28103727, -0.21342745,  0.4211418 , ...,  0.03504564,
#          -0.0930341 , -0.5101348 ],
#         [-0.23481484,  0.1020364 , -0.25905165, ..., -0.16174904,
#          -0.02359565, -0.00467251],
#         [ 0.05984345,  0.03070013, -0.2350889 , ...,  0.24699333,
#           0.07585265,  0.02419994],
#         ...,
#         [ 0.3973136 ,  0.20297825,  0.02115336, ...,  0.26307708,
#           0.12307519,  0.14386182],
#         [ 0.0931767 , -0.05478242, -0.10843732, ...,  0.01894388,
#          -0.37418315, -0.45126966],
#         [ 0.00570232,  0.17054583,  0.3424345 , ..., -0.02093158,
#          -0.273806  , -0.57112086]], dtype=float32)>,
#  <tf.Variable 'UnreadVariable' shape=(256, 768) dtype=float32, numpy=
#  array([[ 1.4915878 , -0.34397808,  0.2248008 , ..., -0.04719142,
#          -0.10927679,  0.32413903],
#         [-0.01399645,  0.14975034,  0.39371124, ..., -0.06637376,
#           0.07391087,  0.09818999],
#         [-0.28600362, -0.17731526,  0.11225829, ..., -0.24162059,
#           0.2882674 ,  0.46865174],
#         ...,
#         [-0.2730321 ,  0.14262252, -0.12477551, ..., -0.11774972,
#          -0.08747908,  0.00424929],
#         [ 0.64458376, -0.19919147,  0.33947012, ..., -0.20799045,
#           0.3167488 , -0.08119893],
#         [ 0.65560776,  0.11946817, -0.37314624, ..., -0.5493829 ,
#          -0.26485842, -0.22199425]], dtype=float32)>,
#  <tf.Variable 'UnreadVariable' shape=(2, 768) dtype=float32, numpy=
#  array([[-0.15696695, -0.23226334,  0.19319585, ..., -0.06932688,
#          -0.00538722, -0.10696251],
#         [-0.15696695, -0.23226334,  0.19319585, ..., -0.05464124,
#           0.14779326, -0.4589359 ]], dtype=float32)>,
#  <tf.Variable 'UnreadVariable' shape=(256, 8004) dtype=float32, numpy=
#  array([[-0.14199293, -0.13999519, -0.26024818, ...,  0.4832342 ,
#           0.14026701, -0.53266305],
#         [-0.10119975,  0.09412197, -0.12685044, ...,  0.07155105,
#          -0.03454883,  0.37040353],
#         [ 0.00762525,  0.4339051 ,  0.34055105, ...,  0.12078573,
#          -0.19057977, -0.05961904],
#         ...,
#         [ 0.32094854,  0.24624619, -0.6856977 , ...,  0.12187298,
#          -0.01592659,  0.1276008 ],
#         [ 0.19223066,  0.28892645, -0.02815211, ..., -0.18532455,
#           0.01385047,  0.12400306],
#         [ 0.20537035, -0.1206551 ,  0.26089752, ..., -0.01468389,
#           0.24272439, -0.7317588 ]], dtype=float32)>,
#  <tf.Variable 'UnreadVariable' shape=(8004,) dtype=float32, numpy=
#  array([ 0.00773404, -0.61263156, -0.27636138, ..., -0.28345612,
#         -0.20533367, -0.08090609], dtype=float32)>,
#  <tf.Variable 'UnreadVariable' shape=(8004, 1024) dtype=float32, numpy=
#  array([[ 0.00690273,  0.03005036, -0.11743947, ..., -0.22767411,
#          -0.10645858, -0.11685664],
#         [ 0.05707687,  0.0120826 , -0.15501055, ...,  0.05058194,
#          -0.09599498,  0.07873718],
#         [ 0.00875945,  0.10455434, -0.19779147, ..., -0.04656181,
#          -0.01746915,  0.2019771 ],
#         ...,
#         [ 0.07156011,  0.19026443,  0.12948783, ...,  0.24142708,
#           0.05671677, -0.22555704],
#         [ 0.05790754, -0.08439868, -0.01417062, ..., -0.0079888 ,
#          -0.06536584,  0.01692006],
#         [ 0.05406589, -0.05825644, -0.00128531, ..., -0.05015941,
#           0.09470313,  0.01084097]], dtype=float32)>,
#  <tf.Variable 'UnreadVariable' shape=(1024, 768) dtype=float32, numpy=
#  array([[ 4.40230668e-01,  2.51078576e-01,  1.53241649e-01, ...,
#          -1.85686527e-04, -4.55848426e-02, -1.22358665e-01],
#         [-1.51665077e-01, -9.07627642e-02,  2.36022189e-01, ...,
#          -1.44048929e-01,  2.07594991e-01,  1.41995642e-02],
#         [-2.64646530e-01, -1.10076375e-01, -5.27898371e-01, ...,
#          -3.52743492e-02,  1.44288227e-01,  6.16752021e-02],
#         ...,
#         [-1.33675739e-01,  6.77913725e-02,  2.15469509e-01, ...,
#           3.17949317e-02, -2.74577122e-02,  1.55825734e-01],
#         [-9.56376866e-02, -2.04862610e-01, -9.65036154e-02, ...,
#          -1.77452967e-01,  9.70964953e-02,  1.04341164e-01],
#         [-5.52232116e-02,  4.13691044e-01,  1.55642211e-01, ...,
#           2.27632806e-01,  2.18445975e-02,  1.82497680e-01]], dtype=float32)>,
#  <tf.Variable 'UnreadVariable' shape=(256, 768) dtype=float32, numpy=
#  array([[ 0.21015672, -0.01314562, -0.32387006, ..., -0.16882889,
#          -0.04981519,  0.18188497],
#         [ 0.1358126 ,  0.01420437,  0.16084023, ..., -0.31318325,
#           0.24577533, -0.41315532],
#         [ 0.15746725,  0.17814864, -0.01940768, ...,  0.15469751,
#           0.01854788, -0.09194304],
#         ...,
#         [-0.19782719, -0.10887643, -0.19692451, ...,  0.24649823,
#           0.12199911,  0.04761562],
#         [ 0.18580809, -0.30063584, -0.00958004, ...,  0.13246092,
#           0.36722836,  0.16329962],
#         [ 0.17114875, -0.15436764, -0.11463626, ..., -0.0014947 ,
#           0.10535066,  0.20043866]], dtype=float32)>,
#  <tf.Variable 'UnreadVariable' shape=(2, 768) dtype=float32, numpy=
#  array([[ 8.3980978e-02,  6.7774761e-01, -4.3875719e-03, ...,
#          -3.7570920e-02,  5.0434966e-02,  6.4033747e-04],
#         [ 8.3980978e-02,  6.7774761e-01, -4.3875719e-03, ...,
#           1.6328686e-01,  1.7796102e-03,  2.4120745e-01]], dtype=float32)>,
#  <tf.Variable 'UnreadVariable' shape=(256, 768) dtype=float32, numpy=
#  array([[ 0.11693642,  0.14618385, -0.19464995, ..., -0.14954731,
#          -0.19122256, -0.1880206 ],
#         [ 0.3486427 ,  0.31846485, -0.1851261 , ...,  0.18620785,
#          -0.12095828, -0.04460385],
#         [ 0.15279189, -0.43793556, -0.18305719, ..., -0.2528576 ,
#          -0.04785754, -0.06248782],
#         ...,
#         [ 0.3073659 ,  0.0906162 ,  0.11272907, ..., -0.06778467,
#          -0.4603946 , -0.59303427],
#         [ 0.1619193 ,  0.44059855, -0.34110123, ...,  0.1054242 ,
#          -0.00357926, -0.04257392],
#         [ 0.34478757, -0.07384411,  0.03864406, ..., -0.28291443,
#           0.20886041,  0.02601887]], dtype=float32)>,
#  <tf.Variable 'UnreadVariable' shape=(256, 768) dtype=float32, numpy=
#  array([[-0.3983051 , -0.18894088,  0.14012466, ...,  0.0508748 ,
#          -0.1146738 ,  0.19815531],
#         [-0.00181836, -0.04180841,  0.08993305, ...,  0.02122237,
#          -0.09291507,  0.17229773],
#         [-0.02174757, -0.09666445,  0.3073926 , ..., -0.09782815,
#          -0.16834883,  0.22517563],
#         ...,
#         [ 0.09895109, -0.12193664, -0.15548772, ..., -0.01776754,
#           0.42214936, -0.11690987],
#         [-0.2382293 , -0.01461816,  0.20056058, ...,  0.04065102,
#           0.1974983 , -0.2398449 ],
#         [-0.30933568,  0.6085323 ,  0.13527286, ...,  0.06111754,
#          -0.23234478,  0.21504408]], dtype=float32)>,
#  <tf.Variable 'UnreadVariable' shape=(2, 768) dtype=float32, numpy=
#  array([[ 0.09591216, -0.20507312,  0.1419095 , ..., -0.02102723,
#          -0.01149642, -0.0376258 ],
#         [ 0.09591216, -0.20507312,  0.1419095 , ..., -0.39456213,
#          -0.291612  ,  0.16825369]], dtype=float32)>,
#  <tf.Variable 'UnreadVariable' shape=(256, 768) dtype=float32, numpy=
#  array([[-0.0136017 , -0.08321565,  0.15498883, ...,  0.15705545,
#           0.1338525 ,  0.11224269],
#         [-0.18955703,  0.04794927,  0.00694556, ..., -0.02488115,
#           0.07595535, -0.25002366],
#         [-0.04018497,  0.18027498, -0.16918847, ...,  0.33465856,
#          -0.13083503, -0.05102094],
#         ...,
#         [-0.06525604, -0.26239786,  0.1567555 , ..., -0.10751181,
#          -0.07463984, -0.35445905],
#         [ 0.74185085, -0.45556423, -0.45150083, ...,  0.05582782,
#           0.20602232,  0.23454036],
#         [-0.25288182, -0.14657249, -0.36504066, ..., -0.37443745,
#           0.23931691, -0.30751774]], dtype=float32)>,
#  <tf.Variable 'UnreadVariable' shape=(256, 768) dtype=float32, numpy=
#  array([[ 0.02872303, -0.6632766 ,  0.26151785, ..., -0.32684383,
#           0.10398392,  0.24743669],
#         [-0.19891539,  0.33947027,  0.17931548, ..., -0.4275724 ,
#          -0.00717095, -0.03842138],
#         [-0.08759217, -0.2817269 ,  0.23775193, ..., -0.05219345,
#           0.12912478,  0.04961471],
#         ...,
#         [ 0.56298685, -0.07434593, -0.0179231 , ..., -0.03785538,
#           0.04073388, -0.09541899],
#         [-0.21893716,  0.03465879, -0.41936317, ...,  0.33890447,
#           0.437791  , -0.25574204],
#         [ 0.08177759,  0.19585755, -0.16750962, ..., -0.27140927,
#          -0.3410135 ,  0.10843313]], dtype=float32)>,
#  <tf.Variable 'UnreadVariable' shape=(2, 768) dtype=float32, numpy=
#  array([[ 0.13098931,  0.22821   ,  0.5449822 , ...,  0.09392877,
#          -0.21602264, -0.00731036],
#         [ 0.13098931,  0.22821   ,  0.5449822 , ..., -0.0256596 ,
#          -0.15237463, -0.1990732 ]], dtype=float32)>]

# %% [markdown]
# # Test the model on some basic sentences

# %%
test_questions = ["you can do it", "youre terrible", "nah i dont think so"]

# %%
 for question in test_questions:
    print("Query >", question)
    top_n = 3 # number of top answers needed
    for i in range(top_n):
        sentence = inference(question, top_n)
        print(" >", ' '.join(sentence))
# Out:
# Query > you can do it
#  > yes only
#  > yes jabez lovely now hurry there alone
#  > yes jabez i think youll keep her alone
# Query > youre terrible
#  > some arent getting on going home to unk
#  > some goddamn guy what do i say look what the hell is out now
#  > some day why shouldnt it be back why
# Query > nah i dont think so
#  > if anything meant asking
#  > if anything didnt answer the unk
#  > if you dont hear that duffy or hear you
